# %%
from mom6_forge.grid import Grid

# %%
grid = Grid.from_supergrid("/Users/manishrv/Downloads/tripolargrid.nc")

# %%
grid.supergrid.is_tripolar
# Out:
# True

# %%
grid.supergrid.x[-1]
# Out:
# array([-287., -287., -287., ...,   73.,   73.,   73.], shape=(1081,))

# %%
import matplotlib.pyplot as plt
grid.supergrid.x[-1].plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 grid.supergrid.x[-1].plot()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'
